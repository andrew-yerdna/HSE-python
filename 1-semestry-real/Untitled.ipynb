# %%
f = open('datasets/visit_log.csv', 'r', encoding='utf-8')

# %%
an = f.readline()

# %%
an.strip().split(',')
# Out:
# ['96064ae9e0', 'other']

# %%
next(f)
# Out:
# '6450655ae8,other\n'

# %%
f.close()

# %%
with open('datasets/visit_log.csv', 'r', encoding='utf-8') as f

    f.write('sdfsfsdf')
# Out:
#   Cell In[22], line 1
#     with open('datasets/visit_log.csv', 'r', encoding='utf-8') as f
#                                                                    ^
# SyntaxError: expected ':'
